# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f23cd60e-dd8c-4d07-95d6-da3c3f84aaa1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f23cd60e-dd8c-4d07-95d6-da3c3f84aaa1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io

# %%
df=pd.read_csv(io.BytesIO(uploaded['Tamilnadu agriculture yield data.csv']))

# %%
df.head()
# Out:
#    State_Name District_Name  Crop_Year      Season       Crop   Area  \
# 0  Tamil Nadu      ARIYALUR       2008      Kharif       Rice  24574
# 1  Tamil Nadu      ARIYALUR       2008  Whole Year  Arhar/Tur    209
# 2  Tamil Nadu      ARIYALUR       2008  Whole Year      Bajra    565
# 3  Tamil Nadu      ARIYALUR       2008  Whole Year     Banana    190
# 4  Tamil Nadu      ARIYALUR       2008  Whole Year  Cashewnut  31113
#
#    Production                       Soil Type
# 0         NaN  Limestone Ferruginous red loam
# 1         NaN  Limestone Ferruginous red loam
# 2         NaN  Limestone Ferruginous red loam
# 3         NaN  Limestone Ferruginous red loam
# 4         NaN  Limestone Ferruginous red loam

# %%
#Basic information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13547 entries, 0 to 13546
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State_Name     13547 non-null  object
#  1   District_Name  13547 non-null  object
#  2   Crop_Year      13547 non-null  int64
#  3   Season         13547 non-null  object
#  4   Crop           13547 non-null  object
#  5   Area           13547 non-null  int64
#  6   Production     13266 non-null  float64
#  7   Soil Type      13547 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 846.8+ KB

# %%
df=df[df['District_Name']=="ARIYALUR"]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State_Name     0 non-null      object
#  1   District_Name  0 non-null      object
#  2   Crop_Year      0 non-null      int64
#  3   Season         0 non-null      object
#  4   Crop           0 non-null      object
#  5   Area           0 non-null      int64
#  6   Production     0 non-null      float64
#  7   Soil Type      0 non-null      object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 0.0+ bytes

# %%
#to check  for any null values
df.isnull().sum()
# Out:
# State_Name        0
# District_Name     0
# Crop_Year         0
# Season            0
# Crop              0
# Area              0
# Production       24
# Soil Type         0
# dtype: int64

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [State_Name, District_Name, Crop_Year, Season, Crop, Area, Production, Soil Type]
# Index: []

# %% [markdown]
# CORRELATION HEATMAP

# %%
import matplotlib.pyplot as plt
import seaborn as sb
C_mat=df.corr()
fig=plt.figure(figsize=(5,5))
sb.heatmap(C_mat,vmax=1,square=True)
plt.show()

# %%
df=df[df['Crop_Year']>=2012]
df
# Out:
# Empty DataFrame
# Columns: [State_Name, District_Name, Crop_Year, Season, Crop, Area, Production, Soil Type]
# Index: []
